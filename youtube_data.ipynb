# %%
import requests 
import warnings

# %%
import pandas as pd

# %%
from bs4 import BeautifulSoup

# %%
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('channel_link.csv')

# %%
df
# Out:
#                                     channel  \
# 0                                    Rotana
# 1                                  mmoshaya
# 2     شبكة العاب العرب | Arab Games Network
# 3                           Katakit Baby TV
# 4                               ماشا و الدب
# ...                                     ...
# 3557                            SportsBD.TV
# 3558                            jadidal3alm
# 3559                              News. Com
# 3560                           Aflaming Boy
# 3561                               shakshak
#
#                                                    link
# 0                                /rotana/youtuber-stats
# 1                              /mmoshaya/youtuber-stats
# 2                    /arab-games-network/youtuber-stats
# 3                       /katakit-baby-tv/youtuber-stats
# 4     /27c0810d-bede-41cb-a6a6-d09e6aeb777e/youtuber...
# ...                                                 ...
# 3557                        /sportsbd-tv/youtuber-stats
# 3558                        /jadidal3alm/youtuber-stats
# 3559  /news-com-15367171-da37-4aee-a30f-f8cac4d25125...
# 3560                       /aflaming-boy/youtuber-stats
# 3561                           /shakshak/youtuber-stats
#
# [3562 rows x 2 columns]

# %%
# columns = [ 
#             'profile_name', 
#             'subscriber', 
#             'view',
#             'video',
#             'country',
#             'category',
#             'since',
#             'month_earnings',
#             'last_subscriber_30',
#             'last_view_30',
#             'overviewSubscribers',
#             'overviewVideoViews',
#           ]

# %%
# df1 = pd.DataFrame(columns=columns)

# %%
# df1 = pd.read_csv('youtube_data.csv')

# %%
index = df.shape[0]

# %%
for ind in range(0, index):
    # assign URL 
    url_to_scrape = "https://us.youtubers.me"

    url = url_to_scrape + df.loc[ind, :][1]

    # request for HTML document of given url 
    response = requests.get(url)

    # Ensure the content is interpreted as UTF-8
    response.encoding = 'utf-8'

    # create document 
    html_document = response.text

    # create soap object 
    soup = BeautifulSoup(html_document, 'html.parser')
    
    info = soup.find_all(attrs = { 'class' : 'status-info' })[0]
    
    profile_name = info.find_all(attrs = { 'class' : 'profile-name' })[0].find('span').text
    subscriber = info.find_all(attrs = { 'class' : 'status-details' })[0].find_all(attrs = { 'class' : 'bottom-part' })[0].text.replace('\n', '').replace(' ', '')
    view = info.find_all(attrs = { 'class' : 'status-details' })[0].find_all(attrs = { 'class' : 'bottom-part' })[1].text.replace('\n', '').replace(' ', '')
    video = info.find_all(attrs = { 'class' : 'status-details' })[0].find_all(attrs = { 'class' : 'bottom-part' })[2].text.replace('\n', '').replace(' ', '')
    country = info.find_all(attrs = { 'class' : 'status-details' })[0].find_all(attrs = { 'class' : 'bottom-part' })[3].text.replace('\n', '')
    category = info.find_all(attrs = { 'class' : 'status-details' })[0].find_all(attrs = { 'class' : 'bottom-part' })[4].text.replace('\n', '')
    since = info.find_all(attrs = { 'class' : 'status-details' })[0].find_all(attrs = { 'class' : 'bottom-part' })[5].text.replace('\n', '').replace(' ', '')

    month_earnings = soup.find_all(attrs = { 'class' : 'overview' })[0].find_all(attrs = { 'class' : 'bottom' })[3].text.replace('\n', '').replace(' ', '').split('-')
    last_subscriber_30 = soup.find_all(attrs = { 'class' : 'stats-board three-row' })[0].find_all(attrs = { 'class' : 'top' })[1].text.replace('\n', '').replace(' ', '')
    last_view_30 = soup.find_all(attrs = { 'class' : 'stats-board three-row' })[0].find_all(attrs = { 'class' : 'top' })[4].text.replace('\n', '').replace(' ', '')

    try:
        overviewSubscribers = soup.find_all('script')[7].text
        start = overviewSubscribers.index('date') + 5
        end = overviewSubscribers.index(', {') - 1
        overviewSubscribers = overviewSubscribers[start: end].split('\\n')
        l = []
        for element in overviewSubscribers:
            if ',' in element:
                l.append(element.split(','))
        overviewSubscribers = l
    except:
        overviewSubscribers = None

    try:
        overviewVideoViews = soup.find_all('script')[8].text
        start = overviewVideoViews.index('date') + 5
        end = overviewVideoViews.index(', {') - 1
        overviewVideoViews = overviewVideoViews[start: end].split('\\n')
        l = []
        for element in overviewVideoViews:
            if ',' in element:
                l.append(element.split(','))
        overviewVideoViews = l
    except:
        overviewVideoViews = None
    
    di = {
        'profile_name' : [profile_name],
        'subscriber' : [subscriber],
        'view' : [view],
        'video' : [video],
        'country' : [country],
        'category' : [category],
        'since' : [since],
        'month_earnings' : [month_earnings],
        'last_subscriber_30' : [last_subscriber_30],
        'last_view_30' : [last_view_30],
        'overviewSubscribers' : [overviewSubscribers],
        'overviewVideoViews' : [overviewVideoViews],
    }

    df2 = pd.DataFrame(di)
    df1 = pd.concat([df1, df2], axis = 0)

# %%
df1.reset_index(drop=True, inplace=True)

# %%
df1
# Out:
#                                profile_name  subscriber            view video  \
# 0                                    Rotana  24,500,000  24,034,368,999  9078
# 1                                  Mmoshaya  23,200,000  18,468,679,361  1240
# 2     شبكة العاب العرب | Arab Games Network  22,300,000  10,024,125,023  7460
# 3                           Katakit Baby Tv  20,200,000   8,517,744,618   231
# 4                               ماشا و الدب  18,300,000  10,158,387,659  1482
# ...                                     ...         ...             ...   ...
# 3557                           Sports Bd.Tv           0         185,482   492
# 3558                            Jadidal3alm           0         603,444   254
# 3559                              News. Com           0       6,599,820   372
# 3560                           Aflaming Boy           0      75,874,878   272
# 3561                               Shakshak           0          13,514     4
#
#                 country         category since        month_earnings  \
# 0     Saudi Arabia (SA)            Music  2012    ['$110K', '$658K']
# 1     Saudi Arabia (SA)   People & Blogs  2010  ['$12.8K', '$76.7K']
# 2     Saudi Arabia (SA)           Gaming  2013     ['$17K', '$102K']
# 3     Saudi Arabia (SA)            Music  2010     ['$50K', '$300K']
# 4     Saudi Arabia (SA)            Shows  2017   ['$30.8K', '$185K']
# ...                 ...              ...   ...                   ...
# 3557  Saudi Arabia (SA)           Sports  2016           [$60, $363]
# 3558  Saudi Arabia (SA)  News & Politics  2016        [$226, $1.36K]
# 3559  Saudi Arabia (SA)           Comedy  2014           [$76, $456]
# 3560  Saudi Arabia (SA)           Comedy  2017        [$625, $3.75K]
# 3561  Saudi Arabia (SA)    Entertainment  2016             [$5, $30]
#
#      last_subscriber_30 last_view_30  \
# 0               200,000  292,453,337
# 1                     0   34,076,848
# 2               100,000   45,416,699
# 3               200,000  133,417,200
# 4               100,000   82,126,847
# ...                 ...          ...
# 3557                  0      161,430
# 3558                  0      603,444
# 3559                  0      203,070
# 3560                  0    1,668,057
# 3561                  0       13,514
#
#                                     overviewSubscribers  \
# 0     [['2016-10-29', '3282041'], ['2016-11-27', '33...
# 1     [['2016-10-27', '1139825'], ['2016-11-23', '12...
# 2     [['2016-11-14', '213303'], ['2017-01-19', '250...
# 3     [['2021-07-18', '9780000'], ['2021-08-31', '10...
# 4     [['2017-05-29', '967'], ['2017-06-18', '5106']...
# ...                                                 ...
# 3557  [[2016-11-05, 0], [2016-11-06, 0], [2016-11-07...
# 3558                                  [[2017-03-10, 0]]
# 3559  [[2017-03-09, 0], [2017-03-10, 0], [2017-03-11...
# 3560  [[2017-12-17, 0], [2018-01-12, 0], [2018-01-30...
# 3561                                  [[2017-03-05, 0]]
#
#                                      overviewVideoViews
# 0     [['2016-10-29', '2397995058'], ['2016-11-27', ...
# 1     [['2016-10-27', '340585176'], ['2016-11-23', '...
# 2     [['2016-11-14', '22399237'], ['2017-01-19', '3...
# 3     [['2021-07-18', '3675162082'], ['2021-08-31', ...
# 4     [['2017-05-29', '135030'], ['2017-06-18', '973...
# ...                                                 ...
# 3557  [[2016-11-05, 5191], [2016-11-06, 5228], [2016...
# 3558                             [[2017-03-10, 603444]]
# 3559  [[2017-03-09, 7568469], [2017-03-10, 7568469],...
# 3560  [[2017-12-17, 1153520], [2018-01-12, 5395591],...
# 3561                              [[2017-03-05, 13514]]
#
# [3562 rows x 12 columns]

# %%
df1.to_csv('youtube_data.csv', index=False)

# %%
df1.isnull().sum()
# Out:
# profile_name             0
# subscriber               0
# view                     0
# video                    0
# country                  0
# category               359
# since                    0
# month_earnings           0
# last_subscriber_30       0
# last_view_30             0
# overviewSubscribers      2
# overviewVideoViews       2
# dtype: int64

# %%
df1[df1['category'].isnull()]
# Out:
#                   profile_name  subscriber            view  video  \
# 5     قناة وناسة    Wanasah Tv  18,100,000  10,219,433,723    233
# 59                  Ahmed Best   5,030,000     220,779,894     56
# 91                Adel Belarbi   3,950,000     864,238,883   1114
# 96                  Ahmed Sega   3,790,000   1,587,074,655   2637
# 104     Anas Action   أنس آكشن   3,640,000     344,643,092    123
# ...                        ...         ...             ...    ...
# 3441             Mbc Bollywood           0               0      0
# 3451     تجميع هجمات الحيوانات           0       2,819,124     88
# 3469      Toys And Little Gaby           0      26,873,274     32
# 3519            Mbc Plus Drama           0          73,275      1
# 3543                Mbc Action           0               0      0
#
#                 country category  since        month_earnings  \
# 5     Saudi Arabia (SA)      NaN   2014   ['$45.8K', '$275K']
# 59    Saudi Arabia (SA)      NaN   2021  ['$2.27K', '$13.6K']
# 91    Saudi Arabia (SA)      NaN   2016  ['$8.51K', '$51.1K']
# 96    Saudi Arabia (SA)      NaN   2011  ['$6.72K', '$40.3K']
# 104   Saudi Arabia (SA)      NaN   2016       ['$2K', '$12K']
# ...                 ...      ...    ...                   ...
# 3441  Saudi Arabia (SA)      NaN   2017          ['$0', '$0']
# 3451  Saudi Arabia (SA)      NaN   2016  ['$1.51K', '$9.06K']
# 3469  Saudi Arabia (SA)      NaN   2018   ['$6.8K', '$40.8K']
# 3519  Saudi Arabia (SA)      NaN   2017          ['$0', '$0']
# 3543  Saudi Arabia (SA)      NaN   2017          ['$0', '$0']
#
#      last_subscriber_30 last_view_30  \
# 5               300,000  122,245,986
# 59               70,000    6,057,329
# 91              210,000   22,703,043
# 96               40,000   17,924,096
# 104              50,000    5,331,957
# ...                 ...          ...
# 3441                  0            0
# 3451                  0    4,025,250
# 3469                  0   18,146,250
# 3519                  0          420
# 3543                  0            0
#
#                                     overviewSubscribers  \
# 5     [['2024-09-01', '17300000'], ['2024-09-04', '1...
# 59    [['2023-02-11', '3000000'], ['2023-02-18', '30...
# 91    [['2024-03-31', '1510000'], ['2024-04-04', '15...
# 96    [['2024-02-25', '2610000'], ['2024-02-28', '26...
# 104   [['2022-12-23', '1130000'], ['2022-12-30', '11...
# ...                                                 ...
# 3441  [['2017-08-12', '0'], ['2017-08-14', '0'], ['2...
# 3451  [['2016-11-09', '0'], ['2016-11-10', '0'], ['2...
# 3469         [['2019-05-08', '0'], ['2019-05-09', '0']]
# 3519  [['2017-08-12', '0'], ['2017-08-14', '0'], ['2...
# 3543  [['2017-08-12', '0'], ['2017-08-14', '0'], ['2...
#
#                                      overviewVideoViews
# 5     [['2024-09-01', '9725512034'], ['2024-09-04', ...
# 59    [['2023-02-11', '168415646'], ['2023-02-18', '...
# 91    [['2024-03-31', '491367433'], ['2024-04-04', '...
# 96    [['2024-02-25', '1142997906'], ['2024-02-28', ...
# 104   [['2022-12-23', '69614343'], ['2022-12-30', '7...
# ...                                                 ...
# 3441  [['2017-08-12', '0'], ['2017-08-14', '0'], ['2...
# 3451  [['2016-11-09', '2323870'], ['2016-11-10', '23...
# 3469  [['2019-05-08', '26268399'], ['2019-05-09', '2...
# 3519  [['2017-08-12', '70227'], ['2017-08-14', '7027...
# 3543  [['2017-08-12', '0'], ['2017-08-14', '0'], ['2...
#
# [359 rows x 12 columns]

# %%
df1.loc[1930, :]
# Out:
# profile_name                                                      SKoRSA
# subscriber                                                        51,600
# view                                                           1,483,364
# video                                                                174
# country                                                Saudi Arabia (SA)
# category                                                             NaN
# since                                                               2015
# month_earnings                                              ['$0', '$0']
# last_subscriber_30                                                     0
# last_view_30                                                         138
# overviewSubscribers    [['2023-07-19', '53100'], ['2023-07-24', '5310...
# overviewVideoViews     [['2023-07-19', '1473039'], ['2023-07-24', '14...
# Name: 1930, dtype: object

# %%
# df1.loc[1109, 'profile_name'] = 'آيات'

# %%
# df1.loc[1930, 'profile_name'] = 'SKoRSA'
