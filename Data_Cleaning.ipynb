# %%
import warnings

# %%
import numpy as np
import pandas as pd

# %%
import plotly.graph_objects as go
import plotly.express as px

# %%
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('Data/youtube_data.csv')

# %%
df
# Out:
#       Unnamed: 0  index                           profile_name  subscriber  \
# 0              0      0                                 Rotana    24500000
# 1              1      1                               Mmoshaya    23200000
# 2              2      2  شبكة العاب العرب | Arab Games Network    22300000
# 3              3      3                        Katakit Baby Tv    20200000
# 4              4      4                            ماشا و الدب    18300000
# ...          ...    ...                                    ...         ...
# 3578        3578   3580                      Thunayyan Khalid!     3890000
# 3579        3579   3581              دانية شافعي Danyah Shafei     2830000
# 3580        3580   3582                              25esports      348000
# 3581        3581   3583                           Barry | باري     1780000
# 3582        3582   3584                          Dyler | دايلر     7860000
#
#              view  video            country          category  since  \
# 0     24034368999   9078  Saudi Arabia (SA)             Music   2012
# 1     18468679361   1240  Saudi Arabia (SA)    People & Blogs   2010
# 2     10024125023   7460  Saudi Arabia (SA)            Gaming   2013
# 3      8517744618    231  Saudi Arabia (SA)             Music   2010
# 4     10158387659   1482  Saudi Arabia (SA)             Shows   2017
# ...           ...    ...                ...               ...    ...
# 3578    755411009    595        Canada (CA)     Entertainment   2010
# 3579   1160145940    329  Saudi Arabia (SA)  Film & Animation   2013
# 3580     13915866     56  Saudi Arabia (SA)    People & Blogs   2017
# 3581     23957794      1  Saudi Arabia (SA)    People & Blogs   2017
# 3582   1224551963    567  Saudi Arabia (SA)    People & Blogs   2016
#
#       last_subscriber_30  last_view_30  \
# 0                 200000     292453337
# 1                      0      34076848
# 2                 100000      45416699
# 3                 200000     133417200
# 4                 100000      82126847
# ...                  ...           ...
# 3578                   0        455754
# 3579                   0       2757922
# 3580                5000        209635
# 3581                   0         64270
# 3582                   0       1515993
#
#                                     overviewSubscribers  \
# 0     [['2016-10-29', '3282041'], ['2016-11-27', '33...
# 1     [['2016-10-27', '1139825'], ['2016-11-23', '12...
# 2     [['2016-11-14', '213303'], ['2017-01-19', '250...
# 3     [['2021-07-18', '9780000'], ['2021-08-31', '10...
# 4     [['2017-05-29', '967'], ['2017-06-18', '5106']...
# ...                                                 ...
# 3578  [['2016-10-29', '1440927'], ['2016-11-24', '15...
# 3579  [['2016-10-29', '396331'], ['2016-11-23', '439...
# 3580  [['2021-06-17', '230000'], ['2021-07-30', '241...
# 3581  [['2017-03-25', '78157'], ['2017-04-17', '1044...
# 3582  [['2017-01-03', '387'], ['2017-02-15', '132771...
#
#                                      overviewVideoViews  min_month_earnings  \
# 0     [['2016-10-29', '2397995058'], ['2016-11-27', ...              110000
# 1     [['2016-10-27', '340585176'], ['2016-11-23', '...               12800
# 2     [['2016-11-14', '22399237'], ['2017-01-19', '3...               17000
# 3     [['2021-07-18', '3675162082'], ['2021-08-31', ...               50000
# 4     [['2017-05-29', '135030'], ['2017-06-18', '973...               30800
# ...                                                 ...                 ...
# 3578  [['2016-10-29', '195190546'], ['2016-11-24', '...                 170
# 3579  [['2016-10-29', '271407735'], ['2016-11-23', '...                1030
# 3580  [['2021-06-17', '4042277'], ['2021-07-30', '48...                  78
# 3581  [['2017-03-25', '172750'], ['2017-04-17', '716...                  24
# 3582  [['2017-01-03', '0'], ['2017-02-15', '2639847'...                 568
#
#       max_month_earnings
# 0                 658000
# 1                  76700
# 2                 102000
# 3                 300000
# 4                 185000
# ...                  ...
# 3578                1030
# 3579                6210
# 3580                 471
# 3581                 144
# 3582                3410
#
# [3583 rows x 15 columns]

# %%
index = df.shape[0]

# %%
nindex = df[df['overviewSubscribers'].isna()].index

# %%
for i in nindex:
   df.at[i, 'overviewSubscribers'] = []

# %%
overviewSubscribers_date = []

# %%
overviewSubscribers_count = []

# %%
for i in range(0, index):
     yde = df.loc[i, ['overviewSubscribers']][0]
     if not yde == []:
         yde = eval(yde)
         a = []
         b = []
         for element in yde:
             a.append(element[0])
             b.append(element[1])
         overviewSubscribers_date.append(a)
         overviewSubscribers_count.append(b)
     else:
         overviewSubscribers_date.append([])
         overviewSubscribers_count.append([])

# %%
df['overviewSubscribers_date'] = overviewSubscribers_date

# %%
df['overviewSubscribers_count'] = overviewSubscribers_count

# %%
nindex = df[df['overviewVideoViews'].isna()].index

# %%
for i in nindex:
     df.at[i, 'overviewVideoViews'] = []

# %%
overviewVideoViews_date = []

# %%
overviewVideoViews_count = []

# %%
for i in range(0, index):
    yde = df.loc[i, ['overviewVideoViews']][0]
    if not yde == []:
         yde = eval(yde)
         a = [] 
         b = []
         for element in yde:
             a.append(element[0])
             b.append(element[1])
         overviewVideoViews_date.append(a)
         overviewVideoViews_count.append(b)
    else:
        overviewVideoViews_date.append([])
        overviewVideoViews_count.append([])

# %%
df['overviewVideoViews_date'] = overviewVideoViews_date

# %%
df['overviewVideoViews_count'] = overviewVideoViews_count

# %%
df
# Out:
#       Unnamed: 0  index                           profile_name  subscriber  \
# 0              0      0                                 Rotana    24500000
# 1              1      1                               Mmoshaya    23200000
# 2              2      2  شبكة العاب العرب | Arab Games Network    22300000
# 3              3      3                        Katakit Baby Tv    20200000
# 4              4      4                            ماشا و الدب    18300000
# ...          ...    ...                                    ...         ...
# 3578        3578   3580                      Thunayyan Khalid!     3890000
# 3579        3579   3581              دانية شافعي Danyah Shafei     2830000
# 3580        3580   3582                              25esports      348000
# 3581        3581   3583                           Barry | باري     1780000
# 3582        3582   3584                          Dyler | دايلر     7860000
#
#              view  video            country          category  since  \
# 0     24034368999   9078  Saudi Arabia (SA)             Music   2012
# 1     18468679361   1240  Saudi Arabia (SA)    People & Blogs   2010
# 2     10024125023   7460  Saudi Arabia (SA)            Gaming   2013
# 3      8517744618    231  Saudi Arabia (SA)             Music   2010
# 4     10158387659   1482  Saudi Arabia (SA)             Shows   2017
# ...           ...    ...                ...               ...    ...
# 3578    755411009    595        Canada (CA)     Entertainment   2010
# 3579   1160145940    329  Saudi Arabia (SA)  Film & Animation   2013
# 3580     13915866     56  Saudi Arabia (SA)    People & Blogs   2017
# 3581     23957794      1  Saudi Arabia (SA)    People & Blogs   2017
# 3582   1224551963    567  Saudi Arabia (SA)    People & Blogs   2016
#
#       last_subscriber_30  last_view_30  \
# 0                 200000     292453337
# 1                      0      34076848
# 2                 100000      45416699
# 3                 200000     133417200
# 4                 100000      82126847
# ...                  ...           ...
# 3578                   0        455754
# 3579                   0       2757922
# 3580                5000        209635
# 3581                   0         64270
# 3582                   0       1515993
#
#                                     overviewSubscribers  \
# 0     [['2016-10-29', '3282041'], ['2016-11-27', '33...
# 1     [['2016-10-27', '1139825'], ['2016-11-23', '12...
# 2     [['2016-11-14', '213303'], ['2017-01-19', '250...
# 3     [['2021-07-18', '9780000'], ['2021-08-31', '10...
# 4     [['2017-05-29', '967'], ['2017-06-18', '5106']...
# ...                                                 ...
# 3578  [['2016-10-29', '1440927'], ['2016-11-24', '15...
# 3579  [['2016-10-29', '396331'], ['2016-11-23', '439...
# 3580  [['2021-06-17', '230000'], ['2021-07-30', '241...
# 3581  [['2017-03-25', '78157'], ['2017-04-17', '1044...
# 3582  [['2017-01-03', '387'], ['2017-02-15', '132771...
#
#                                      overviewVideoViews  min_month_earnings  \
# 0     [['2016-10-29', '2397995058'], ['2016-11-27', ...              110000
# 1     [['2016-10-27', '340585176'], ['2016-11-23', '...               12800
# 2     [['2016-11-14', '22399237'], ['2017-01-19', '3...               17000
# 3     [['2021-07-18', '3675162082'], ['2021-08-31', ...               50000
# 4     [['2017-05-29', '135030'], ['2017-06-18', '973...               30800
# ...                                                 ...                 ...
# 3578  [['2016-10-29', '195190546'], ['2016-11-24', '...                 170
# 3579  [['2016-10-29', '271407735'], ['2016-11-23', '...                1030
# 3580  [['2021-06-17', '4042277'], ['2021-07-30', '48...                  78
# 3581  [['2017-03-25', '172750'], ['2017-04-17', '716...                  24
# 3582  [['2017-01-03', '0'], ['2017-02-15', '2639847'...                 568
#
#       max_month_earnings                           overviewSubscribers_date  \
# 0                 658000  [2016-10-29, 2016-11-27, 2016-12-19, 2017-01-1...
# 1                  76700  [2016-10-27, 2016-11-23, 2016-12-23, 2017-01-1...
# 2                 102000  [2016-11-14, 2017-01-19, 2017-05-01, 2017-05-2...
# 3                 300000  [2021-07-18, 2021-08-31, 2021-09-27, 2021-10-2...
# 4                 185000  [2017-05-29, 2017-06-18, 2017-07-09, 2017-08-1...
# ...                  ...                                                ...
# 3578                1030  [2016-10-29, 2016-11-24, 2016-12-28, 2017-01-2...
# 3579                6210  [2016-10-29, 2016-11-23, 2017-01-28, 2017-08-0...
# 3580                 471  [2021-06-17, 2021-07-30, 2021-09-06, 2021-10-0...
# 3581                 144  [2017-03-25, 2017-04-17, 2017-05-09, 2017-06-0...
# 3582                3410  [2017-01-03, 2017-02-15, 2017-08-07, 2017-10-0...
#
#                               overviewSubscribers_count  \
# 0     [3282041, 3394305, 3477819, 3594154, 3799683, ...
# 1     [1139825, 1236408, 1386016, 1491742, 1706496, ...
# 2     [213303, 250934, 313996, 329298, 388002, 56738...
# 3     [9780000, 10100000, 10300000, 10600000, 108000...
# 4     [967, 5106, 14636, 39196, 52839, 75439, 93525,...
# ...                                                 ...
# 3578  [1440927, 1517067, 1626937, 1748880, 1907597, ...
# 3579  [396331, 439363, 490322, 653386, 868361, 92343...
# 3580  [230000, 241000, 250000, 259000, 265000, 26700...
# 3581  [78157, 104496, 111980, 118654, 123445, 135543...
# 3582  [387, 132771, 1145825, 1728665, 1935205, 21126...
#
#                                 overviewVideoViews_date  \
# 0     [2016-10-29, 2016-11-27, 2016-12-19, 2017-01-1...
# 1     [2016-10-27, 2016-11-23, 2016-12-23, 2017-01-1...
# 2     [2016-11-14, 2017-01-19, 2017-05-01, 2017-05-2...
# 3     [2021-07-18, 2021-08-31, 2021-09-27, 2021-10-2...
# 4     [2017-05-29, 2017-06-18, 2017-07-09, 2017-08-1...
# ...                                                 ...
# 3578  [2016-10-29, 2016-11-24, 2016-12-28, 2017-01-2...
# 3579  [2016-10-29, 2016-11-23, 2017-01-28, 2017-08-0...
# 3580  [2021-06-17, 2021-07-30, 2021-09-06, 2021-10-0...
# 3581  [2017-03-25, 2017-04-17, 2017-05-09, 2017-06-0...
# 3582  [2017-01-03, 2017-02-15, 2017-08-07, 2017-10-0...
#
#                                overviewVideoViews_count
# 0     [2397995058, 2517865902, 2599146119, 280588535...
# 1     [340585176, 385899062, 454580517, 525171523, 6...
# 2     [22399237, 30860047, 40045340, 42931914, 51652...
# 3     [3675162082, 3853558289, 3960178435, 408424265...
# 4     [135030, 973753, 3369492, 10535464, 14912931, ...
# ...                                                 ...
# 3578  [195190546, 209416570, 232033553, 251034897, 2...
# 3579  [271407735, 296874955, 330954677, 419697588, 4...
# 3580  [4042277, 4848914, 5570774, 6866796, 7511251, ...
# 3581  [172750, 716716, 820269, 908246, 970854, 10959...
# 3582  [0, 2639847, 94221723, 172927041, 202250421, 2...
#
# [3583 rows x 19 columns]

# %%
columns = [ 
            'profile_name', 
            'date', 
            'views',
          ]
df1 = pd.DataFrame(columns=columns)

# %%
index = df.shape[0]

# %%
temp1 = df.loc[i, :]
print(f"Type: {type(temp1['overviewVideoViews_date'])}, Value: {temp1['overviewVideoViews_date']}")
# Out:
# Type: <class 'list'>, Value: ['2017-01-03', '2017-02-15', '2017-08-07', '2017-10-05', '2017-10-25', '2017-11-13', '2017-12-06', '2017-12-31', '2018-01-21', '2018-02-09', '2018-03-09', '2018-04-13', '2018-05-19', '2018-06-21', '2018-07-22', '2018-08-13', '2018-09-03', '2018-09-23', '2018-10-14', '2018-11-05', '2018-11-29', '2018-12-20', '2019-01-11', '2019-02-08', '2019-02-26', '2019-03-17', '2019-04-09', '2019-04-28', '2019-05-19', '2019-06-17', '2019-07-21', '2019-08-30', '2019-10-19', '2019-12-04', '2020-01-08', '2020-02-09', '2020-07-24', '2021-03-02', '2021-07-11', '2021-11-18', '2022-03-21', '2022-06-25', '2022-10-08', '2022-12-01', '2023-02-05', '2023-04-09', '2023-07-21', '2023-11-30', '2024-03-05', '2024-05-24', '2024-08-19', '2024-11-21']

# %%
import pandas as pd

df2 = pd.DataFrame()  # DataFrame نهائي لتخزين النتائج
years = list(map(str, range(2016, 2025)))  # السنوات المطلوبة (2016-2024)

for i in range(0, index):  # تكرار لعدد معين من الصفوف
    temp = df.loc[i, :]
    overviewVideoViews_date = temp['overviewVideoViews_date']
    overviewVideoViews_count = temp['overviewVideoViews_count']

    # إنشاء DataFrame للبيانات
    dfa = pd.DataFrame({
        'overviewVideoViews_date': overviewVideoViews_date,
        'overviewVideoViews_count': overviewVideoViews_count
    })

    # حساب الفرق السنوي بنفس المنطق الموجود في الكود الأصلي
    di = {}
    for k in range(dfa.shape[0]):
        date = dfa.loc[k, 'overviewVideoViews_date']
        count = int(dfa.loc[k, 'overviewVideoViews_count'])
        year = date[:4]
        di[year] = count

    di_key = list(di.keys())
    di_value = list(di.values())
    di_a = {}
    for j in range(len(di_key) - 1, -1, -1):
        if j > 0:
            di_a[di_key[j]] = abs(di_value[j] - di_value[j - 1])
        else:
            di_a[di_key[j]] = di_value[j]

    # ضمان وجود جميع السنوات في النتيجة النهائية
    output = {f"{year}_views": di_a.get(year, 0) for year in years}

    # تحويل النتائج إلى شكل DataFrame
    df_1 = pd.DataFrame({
        'profile_name': [temp['profile_name']],  # إضافة اسم الملف
        **output
    })

    # دمج البيانات الجديدة مع DataFrame النهائي
    df2 = pd.concat([df2, df_1], axis=0, ignore_index=True)

# النتيجة النهائية
df2.head()
# Out:
#                             profile_name  2016_views  2017_views  2018_views  \
# 0                                 Rotana  2599146119  1562878054  2107864788
# 1                               Mmoshaya   454580517  1450578846  2928599244
# 2  شبكة العاب العرب | Arab Games Network    22399237   129848039   465587480
# 3                        Katakit Baby Tv           0           0           0
# 4                            ماشا و الدب           0    46853112   393684395
#
#    2019_views  2020_views  2021_views  2022_views  2023_views  2024_views
# 0  2117443705  2193280884  3867422692  2912861124  3104603066  3568868567
# 1  3035121331  2349528954  4496597115  2047368285  1020270564   686034505
# 2  1256522354  2299925691  2239806488  1703639572  1010415010   895981152
# 3           0           0  4224521614  1488033470  1306130437  1499059097
# 4   696384101   541672202  2562569016  2542744712  2121583995  1252896126

# %%
df2.shape
# Out:
# (3583, 10)

# %%
import pandas as pd

df3 = pd.DataFrame()  # DataFrame نهائي لتخزين النتائج
years = list(map(str, range(2016, 2025)))  # السنوات المطلوبة (2016-2024)

for i in range(0, index):  # تكرار لعدد معين من الصفوف
    temp = df.loc[i, :]
    overviewVideoViews_date = temp['overviewSubscribers_date']
    overviewVideoViews_count = temp['overviewSubscribers_count']

    # إنشاء DataFrame للبيانات
    dfa = pd.DataFrame({
        'overviewSubscribers_date': overviewVideoViews_date,
        'overviewSubscribers_count': overviewVideoViews_count
    })

    # حساب الفرق السنوي بنفس المنطق الموجود في الكود الأصلي
    di = {}
    for k in range(dfa.shape[0]):
        date = dfa.loc[k, 'overviewSubscribers_date']
        count_str = dfa.loc[k, 'overviewSubscribers_count']

        # التحقق من القيم الفارغة واستبدالها بـ 0
        count = int(count_str) if count_str.strip() else 0

        year = date[:4]
        di[year] = count

    di_key = list(di.keys())
    di_value = list(di.values())
    di_a = {}
    for j in range(len(di_key) - 1, -1, -1):
        if j > 0:
            di_a[di_key[j]] = abs(di_value[j] - di_value[j - 1])
        else:
            di_a[di_key[j]] = di_value[j]

    # ضمان وجود جميع السنوات في النتيجة النهائية
    output = {f"{year}_subscribers": di_a.get(year, 0) for year in years}

    # تحويل النتائج إلى شكل DataFrame
    df_1 = pd.DataFrame({
        'profile_name': [temp['profile_name']],  # إضافة اسم الملف
        **output
    })

    # دمج البيانات الجديدة مع DataFrame النهائي
    df3 = pd.concat([df3, df_1], axis=0, ignore_index=True)

# النتيجة النهائية
df3.head()
# Out:
#                             profile_name  2016_subscribers  2017_subscribers  \
# 0                                 Rotana           3477819           1850288
# 1                               Mmoshaya           1386016           2323147
# 2  شبكة العاب العرب | Arab Games Network            213303            785578
# 3                        Katakit Baby Tv                 0                 0
# 4                            ماشا و الدب                 0            147992
#
#    2018_subscribers  2019_subscribers  2020_subscribers  2021_subscribers  \
# 0           4110479           3361414           2600000           3100000
# 1           5172031           5418806           3200000           3500000
# 2           2845082           3916037           4540000           3300000
# 3                 0                 0                 0          10800000
# 4           1406619           2305389           1300000           4200000
#
#    2022_subscribers  2023_subscribers  2024_subscribers
# 0           2000000           2000000           2000000
# 1           1200000            600000            400000
# 2           1800000           2400000           2500000
# 3           3100000           3000000           3300000
# 4           3740000           3400000           1800000

# %%
df3.shape
# Out:
# (3583, 10)

# %%
df2.drop(["profile_name"],axis=1,inplace=True)
df3.drop(["profile_name"],axis=1,inplace=True)

# %%
df.drop(["Unnamed: 0","index","overviewSubscribers_date","overviewSubscribers_count","overviewVideoViews_date","overviewVideoViews_count","overviewSubscribers","overviewVideoViews"],axis=1,inplace=True)

# %%
df = pd.concat([df, df2], axis=1)

# %%
df = pd.concat([df, df3], axis=1)

# %%
df.head()
# Out:
#                             profile_name  subscriber         view  video  \
# 0                                 Rotana    24500000  24034368999   9078
# 1                               Mmoshaya    23200000  18468679361   1240
# 2  شبكة العاب العرب | Arab Games Network    22300000  10024125023   7460
# 3                        Katakit Baby Tv    20200000   8517744618    231
# 4                            ماشا و الدب    18300000  10158387659   1482
#
#              country        category  since  last_subscriber_30  last_view_30  \
# 0  Saudi Arabia (SA)           Music   2012              200000     292453337
# 1  Saudi Arabia (SA)  People & Blogs   2010                   0      34076848
# 2  Saudi Arabia (SA)          Gaming   2013              100000      45416699
# 3  Saudi Arabia (SA)           Music   2010              200000     133417200
# 4  Saudi Arabia (SA)           Shows   2017              100000      82126847
#
#    min_month_earnings  ...  2024_views  2016_subscribers  2017_subscribers  \
# 0              110000  ...  3568868567           3477819           1850288
# 1               12800  ...   686034505           1386016           2323147
# 2               17000  ...   895981152            213303            785578
# 3               50000  ...  1499059097                 0                 0
# 4               30800  ...  1252896126                 0            147992
#
#    2018_subscribers  2019_subscribers  2020_subscribers  2021_subscribers  \
# 0           4110479           3361414           2600000           3100000
# 1           5172031           5418806           3200000           3500000
# 2           2845082           3916037           4540000           3300000
# 3                 0                 0                 0          10800000
# 4           1406619           2305389           1300000           4200000
#
#    2022_subscribers  2023_subscribers  2024_subscribers
# 0           2000000           2000000           2000000
# 1           1200000            600000            400000
# 2           1800000           2400000           2500000
# 3           3100000           3000000           3300000
# 4           3740000           3400000           1800000
#
# [5 rows x 29 columns]

# %%
df.shape
# Out:
# (3583, 29)

# %%
df.head(10)
# Out:
#                             profile_name  subscriber         view  video  \
# 0                                 Rotana    24500000  24034368999   9078
# 1                               Mmoshaya    23200000  18468679361   1240
# 2  شبكة العاب العرب | Arab Games Network    22300000  10024125023   7460
# 3                        Katakit Baby Tv    20200000   8517744618    231
# 4                            ماشا و الدب    18300000  10158387659   1482
# 5               قناة وناسة    Wanasah Tv    18100000  10219433723    233
# 6                            Banderita X    18000000   5470017529   1887
# 7                           حقائق وأسرار    14800000   2269668104   1544
# 8                             Fantom Pro    13500000   6879804978    622
# 9                          روتانا خليجية    11800000   5124350920  24785
#
#              country          category  since  last_subscriber_30  \
# 0  Saudi Arabia (SA)             Music   2012              200000
# 1  Saudi Arabia (SA)    People & Blogs   2010                   0
# 2  Saudi Arabia (SA)            Gaming   2013              100000
# 3  Saudi Arabia (SA)             Music   2010              200000
# 4  Saudi Arabia (SA)             Shows   2017              100000
# 5  Saudi Arabia (SA)           general   2014              300000
# 6  Saudi Arabia (SA)            Gaming   2013              200000
# 7  Saudi Arabia (SA)     Entertainment   2016                   0
# 8  Saudi Arabia (SA)  Film & Animation   2016              100000
# 9  Saudi Arabia (SA)     Entertainment   2011              100000
#
#    last_view_30  min_month_earnings  ...   2024_views  2016_subscribers  \
# 0     292453337              110000  ...   3568868567           3477819
# 1      34076848               12800  ...    686034505           1386016
# 2      45416699               17000  ...    895981152            213303
# 3     133417200               50000  ...   1499059097                 0
# 4      82126847               30800  ...   1252896126                 0
# 5     122245986               45800  ...  10219433723                 0
# 6      62773474               23500  ...   1144500048                 0
# 7       3796136                1420  ...     22440173            217890
# 8      40297803               15100  ...   2023418457                 0
# 9      57428928               21500  ...   3192515785            872722
#
#    2017_subscribers  2018_subscribers  2019_subscribers  2020_subscribers  \
# 0           1850288           4110479           3361414           2600000
# 1           2323147           5172031           5418806           3200000
# 2            785578           2845082           3916037           4540000
# 3                 0                 0                 0                 0
# 4            147992           1406619           2305389           1300000
# 5                 0                 0                 0                 0
# 6            234606           2432581           2852813           1720000
# 7           1412537           4677686           4391887           1000000
# 8                 0                 0                 0                 0
# 9            782601           1828865           2405812            440000
#
#    2021_subscribers  2022_subscribers  2023_subscribers  2024_subscribers
# 0           3100000           2000000           2000000           2000000
# 1           3500000           1200000            600000            400000
# 2           3300000           1800000           2400000           2500000
# 3          10800000           3100000           3000000           3300000
# 4           4200000           3740000           3400000           1800000
# 5                 0                 0                 0          18100000
# 6           3660000           1400000           1400000           4300000
# 7           2400000            500000            100000            100000
# 8                 0                 0           8210000           5290000
# 9           1170000           1750000           1250000           1300000
#
# [10 rows x 29 columns]
